# %% [markdown]
# # **Crawling Data (Tugas 1)**

# %% [markdown]
# Crawling data adalah proses mengumpulkan data secara otomatis dari berbagai sumber di internet dengan menggunakan program yang disebut "web crawler" atau "spider". Web crawler adalah program yang dirancang untuk mengunjungi situs web dan mengumpulkan informasi yang berguna, seperti teks, gambar, atau link. Data yang dikumpulkan oleh web crawler kemudian dapat dianalisis dan digunakan untuk berbagai keperluan seperti riset pasar, pemantauan harga, analisis sentimen, dan sebagainya. Namun, penting untuk diingat bahwa pengumpulan data secara otomatis dapat melanggar hak cipta atau privasi, sehingga perlu memperhatikan etika dan hukum dalam penggunaannya.

# %% [markdown]
# ## Import Library

# %% [markdown]
# Library yang dibutuhan antara lain:
#
# 1. BeautifulSoup = library untuk mengcrawling data berita
# 2. snscrape = library untuk mengcrawling data twitter
# 3. pandas
# 4. CSV

# %%
# %pip install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting snscrape
#   Downloading snscrape-0.5.0.20230113-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.2/69.2 KB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: pytz in /usr/local/lib/python3.8/dist-packages (from snscrape) (2022.7.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from snscrape) (4.6.3)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.8/dist-packages (from snscrape) (2.25.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from snscrape) (4.9.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from snscrape) (3.9.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (4.0.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->snscrape) (1.7.1)
# Installing collected packages: snscrape
# Successfully installed snscrape-0.5.0.20230113

# %%
import requests as req
from bs4 import BeautifulSoup as bs
from datetime import datetime
import snscrape.modules.twitter as sntwitter
import pandas as pd
import csv

userAgent = {'user-agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Mobile Safari/537.36'}

# %% [markdown]
# ##Crawling data di twitter

# %% [markdown]
# Snscrape adalah sebuah alat yang digunakan untuk melakukan crawling data dari media sosial Twitter. Snscrape memiliki kemampuan untuk mengambil data tweet, pengguna, hashtag, dan topik yang populer pada Twitter.
#
# Untuk menggunakan Snscrape, Anda harus menginstal Python terlebih dahulu. Setelah itu, Anda dapat menginstal Snscrape dengan perintah "pip install snscrape" di terminal. Kemudian, untuk melakukan crawling data Twitter, Anda dapat menjalankan perintah Snscrape di terminal dengan argumen yang sesuai dengan kebutuhan Anda.

# %%
from textblob import TextBlob
import re

# tweets = []
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('Prabowo Subianto Calon Presiden since:2022-01-01 until:2023-02-20').get_items()):
    if i > 1500:
        break
    with open('data-twitter.csv', 'a') as file:
      wr = csv.writer(file, delimiter=',')
      wr.writerow([tweet.date, tweet.user.username, tweet.content])
# tweets_df = pd.DataFrame(tweets, columns=['Datetime', 'Username Twitter', 'Tweet'])
# Out:
# <ipython-input-33-97c48e8fe60c>:10: FutureWarning: content is deprecated, use rawContent instead
#   wr.writerow([tweet.date, tweet.user.username, tweet.content])

# %% [markdown]
# ##Crawliing Jurnal di pta-trunojoyo.ac.id

# %% [markdown]
# Crawling data web dengan Beautiful Soup adalah teknik untuk mengekstrak data dari halaman web dengan menggunakan library Python yang bernama Beautiful Soup. Beautiful Soup menyediakan cara yang mudah untuk menavigasi struktur HTML dan XML dari halaman web, sehingga memungkinkan kita untuk mengambil data yang kita butuhkan.
#
# Pertama-tama, kita harus memuat halaman web yang ingin kita ambil datanya menggunakan library Python seperti requests. Setelah itu, kita dapat menggunakan Beautiful Soup untuk melakukan parsing halaman web tersebut dan mengambil data yang kita butuhkan, seperti teks, gambar, link, dan sebagainya. Beautiful Soup juga dapat digunakan untuk melakukan filtering data berdasarkan kriteria tertentu, seperti tag HTML atau atributnya.
#
# Dalam praktiknya, proses crawling data web dengan Beautiful Soup melibatkan beberapa tahapan seperti mengakses URL, memuat halaman web, melakukan parsing, mengambil data, dan menyimpannya ke dalam format yang sesuai. Meskipun teknik ini relatif mudah dipelajari, namun penting untuk diingat bahwa crawling data web juga memiliki beberapa risiko dan batasan terkait dengan etika, keamanan, dan privasi data.

# %%
a = 1
for page in range(130, 170):
  url = f'https://pta.trunojoyo.ac.id/c_search/byprod/10/{page}'
  ge = req.get(url,userAgent).text
  sop = bs(ge, 'lxml')
  pd = sop.find('div',{'id':'begin'}).find('h2').text
  prodi = ''.join(pd).replace('Journal Jurusan','')
  li = sop.find('ul', class_='items list_style')
  lin = li.find_all('li')
  for x in lin:
    link = x.find('a', class_ ='gray button')['href']
    headline = x.find('div').find('a').text
    headline_ = ''.join(headline).replace('\n','')
    ge_ = req.get(link,userAgent).text
    sop_ = bs(ge_,'lxml')
    nim = x.find('div',{'style':'margin: 25px 0px 15px 0px;'}).find('a', class_='gray button')['href']
    nim_ = ''.join(nim).replace('https://pta.trunojoyo.ac.id/welcome/detail/','')
    content = sop_.find_all('ul', class_='items list_style')
    for x in content:
      nm = x.find('div',{'style':'padding:2px 2px 2px 2px;'}).find('span').text
      nama = ''.join(nm).replace('Penulis : ','')
      x = x.find_all('p')
      y = [y.text for y in x]
      content_ = ''.join(y).replace('\n','')
      print(f'done[{a}] >> {nim_[0:]}')
      a += 1
      with open('pta-trunojoyo.csv', 'a') as file:
        wr = csv.writer(file, delimiter=',')
        wr.writerow([nim_,nama,headline,content_,prodi])
# Out:
# done[1] >> 110411100064
# done[2] >> 110411100097
# done[3] >> 130411100064
# done[4] >> 120411100107
# done[5] >> 100411100060
# done[6] >> 120411100105
# done[7] >> 110411100045
# done[8] >> 140411100073
# done[9] >> 140411100128
# done[10] >> 140411100050
# done[11] >> 140411100024
# done[12] >> 140411100022
# done[13] >> 140411100102
# done[14] >> 110411100019
# done[15] >> 110411100040
# done[16] >> 140411100071
# done[17] >> 140411100092
# done[18] >> 130411100008
# done[19] >> 140411100100
# done[20] >> 140411100091
# done[21] >> 140411100074
# done[22] >> 140411100084
# done[23] >> 120411100022
# done[24] >> 140411100130
# done[25] >> 140411100119
# done[26] >> 140411100142
# done[27] >> 140411100052
# done[28] >> 120411100090
# done[29] >> 140411100098
# done[30] >> 140411100060
# done[31] >> 140411100093
# done[32] >> 120411100018
# done[33] >> 140411100075
# done[34] >> 140411100056
# done[35] >> 140411100029
# done[36] >> 140411100140
# done[37] >> 140411100094
# done[38] >> 130411100015
# done[39] >> 140411100097
# done[40] >> 130411100006
# done[41] >> 130411100010
# done[42] >> 130411100091
# done[43] >> 130411100109
# done[44] >> 110411100007
# done[45] >> 120411100007
# done[46] >> 140411100116
# done[47] >> 140411200150
# done[48] >> 140411100104
# done[49] >> 120411100040
# done[50] >> 110411100018
# done[51] >> 110411100010
# done[52] >> 110411100056
# done[53] >> 140411100106
# done[54] >> 140411100126
# done[55] >> 140411100141
# done[56] >> 140411100146
# done[57] >> 140411100081
# done[58] >> 140411100063
# done[59] >> 140411100096
# done[60] >> 140411100013
# done[61] >> 140411100054
# done[62] >> 140411100088
# done[63] >> 130411100114
# done[64] >> 140411100041
# done[65] >> 140411100017
# done[66] >> 140411100010
# done[67] >> 140411100111
# done[68] >> 170411200130
# done[69] >> 170411200137
# done[70] >> 140411100087
# done[71] >> 140411100070
# done[72] >> 120411100083
# done[73] >> 140411100069
# done[74] >> 140411100011
# done[75] >> 140411100046
# done[76] >> 140411100080
# done[77] >> 140411100118
# done[78] >> 140411100117
# done[79] >> 140411100027
# done[80] >> 140411100020
# done[81] >> 140411100109
# done[82] >> 120411100050
# done[83] >> 140411100048
# done[84] >> 140411200151
# done[85] >> 140411100051
# done[86] >> 140411100085
# done[87] >> 130411100087
# done[88] >> 140411100061
# done[89] >> 120411100015
# done[90] >> 140411100103
# done[91] >> 130411100106
# done[92] >> 140411100044
# done[93] >> 140411100132
# done[94] >> 130411100098
# done[95] >> 130411100011
# done[96] >> 140411100145
# done[97] >> 120411100066
# done[98] >> 140411100124
# done[99] >> 120411100086
# done[100] >> 150411100016
# done[101] >> 150411100052
# done[102] >> 150411100058
# done[103] >> 150411100051
# done[104] >> 150411100001
# done[105] >> 150411100108
# done[106] >> 150411100106
# done[107] >> 150411100078
# done[108] >> 150411100112
# done[109] >> 150411100115
# done[110] >> 150411100091
# done[111] >> 150411100072
# done[112] >> 150411100066
# done[113] >> 150411100061
# done[114] >> 150411100043
# done[115] >> 150411100088
# done[116] >> 170411200135
# done[117] >> 150411100030
# done[118] >> 150411100045
# done[119] >> 140411100082
# done[120] >> 140411100090
# done[121] >> 140411100016
# done[122] >> 140411100137
# done[123] >> 140411100039
# done[124] >> 140411100025
# done[125] >> 140411100042
# done[126] >> 150411100041
# done[127] >> 170411200134
# done[128] >> 170411200133
# done[129] >> 150411100107
# done[130] >> 140411100057
# done[131] >> 150411100017
# done[132] >> 120411100048
# done[133] >> 150411100096
# done[134] >> 140411100009
# done[135] >> 160411200188
# done[136] >> 170411200129
# done[137] >> 140411100031
# done[138] >> 140411100034
# done[139] >> 140411100008
# done[140] >> 150411100021
# done[141] >> 150411100035
# done[142] >> 120411100072
# done[143] >> 170411200128
# done[144] >> 150411100070
# done[145] >> 140411100078
# done[146] >> 140411100143
# done[147] >> 150411100097
# done[148] >> 130411100093
# done[149] >> 150411100029
# done[150] >> 150411100013
# done[151] >> 150411100024
# done[152] >> 150411100027
# done[153] >> 150411100125
# done[154] >> 150411100068
# done[155] >> 150411100121
# done[156] >> 140411100065
# done[157] >> 140411100099
# done[158] >> 140411100043
# done[159] >> 140411100115
# done[160] >> 150411100033
# done[161] >> 140411100053
# done[162] >> 140411100028
# done[163] >> 150411100042
# done[164] >> 140411100120
# done[165] >> 150411100111
# done[166] >> 150411100055
# done[167] >> 150411100025
# done[168] >> 150411100005
# done[169] >> 150411100019
# done[170] >> 150411100074
# done[171] >> 140411100072
# done[172] >> 140411100032
# done[173] >> 130411100074
# done[174] >> 170411200138
# done[175] >> 150411100004
# done[176] >> 150411100031
# done[177] >> 150411100064
# done[178] >> 130411100082
# done[179] >> 130411100094
# done[180] >> 150411100124
# done[181] >> 130411100046
# done[182] >> 150411100123
# done[183] >> 150411100059
# done[184] >> 150411100104
# done[185] >> 140411100045
# done[186] >> 150411100002
# done[187] >> 130411200123
# done[188] >> 130411100034
# done[189] >> 130411100086
# done[190] >> 130411100069
# done[191] >> 130411100053
# done[192] >> 150411100009
# done[193] >> 150411100040
# done[194] >> 150411100003
# done[195] >> 150411100015
# done[196] >> 150411100082
# done[197] >> 170411200127
# done[198] >> 170411200139
# done[199] >> 170411200126
# done[200] >> 150411100084

# %% [markdown]
# ##Crawling Data Berita Online di detik.com

# %%
a = 1
for page in range(0, 30):
  url = f'https://www.detik.com/search/searchall?query=pemilu+2024&sortby=time&page={page}'
  ge = req.get(url,userAgent).text
  sop = bs(ge, 'lxml')
  li = sop.find('div', class_='list media_rows list-berita')
  lin = li.find_all('article')
  for x in lin:
    link = x.find('a')['href']
    headline = x.find('a').find('h2').text
    ge_ = req.get(link,userAgent).text
    sop_ = bs(ge_,'lxml')
    content = sop_.find_all('div', class_='detail__body-text itp_bodycontent')
    for x in content:
      x = x.find_all('p')
      y = [y.text for y in x]
      content_ = ''.join(y).replace('\n','').replace('ADVERTISMENT','').replace('SCROLL TO RESUME CONTENT', '')
      print(f'done[{a}] >> {headline[0:]}')
      a += 1
      with open('beritaonline.csv', 'a') as file:
        wr = csv.writer(file, delimiter=',')
        wr.writerow([headline,content_])
# Out:
# done[1] >> Sudirman Said soal Anies Merosot di Survei Kompas: Belum Kampanye Resmi
# done[2] >> Jabar Hari Ini: Hukuman Lebih Berat untuk Doni Salmanan
# done[3] >> Sudirman Said: Anies Perlu Waktu dan Ketenangan untuk Tentukan Cawapres
# done[4] >> Partai Gelora Pede Jabar Jadi Lumbung Suara di Pemilu 2024
# done[5] >> Anies Dukung Sistem Pemilu Terbuka: Lebih Baik untuk Demokrasi
# done[6] >> Ketua DPP Golkar Tolak Sistem Coblos Partai: Bikin Lupa Turba ke Rakyat
# done[7] >> Bupati Kendal Dico Temui Gibran di Solo, Kaget soal Survei Pilgub Jateng
# done[8] >> Projo Beri Selamat JoMan Dukung Prabowo di Pilpres 2024, Bakal Nyusul?
# done[9] >> Survei POLSTAT Jelang Pemilu 2024: PDIP, Gerindra, dan Demokrat 3 Besar
# done[10] >> Sudirman Said soal Anies Merosot di Survei Kompas: Belum Kampanye Resmi
# done[11] >> Jabar Hari Ini: Hukuman Lebih Berat untuk Doni Salmanan
# done[12] >> Sudirman Said: Anies Perlu Waktu dan Ketenangan untuk Tentukan Cawapres
# done[13] >> Partai Gelora Pede Jabar Jadi Lumbung Suara di Pemilu 2024
# done[14] >> Anies Dukung Sistem Pemilu Terbuka: Lebih Baik untuk Demokrasi
# done[15] >> Ketua DPP Golkar Tolak Sistem Coblos Partai: Bikin Lupa Turba ke Rakyat
# done[16] >> Bupati Kendal Dico Temui Gibran di Solo, Kaget soal Survei Pilgub Jateng
# done[17] >> Projo Beri Selamat JoMan Dukung Prabowo di Pilpres 2024, Bakal Nyusul?
# done[18] >> Survei POLSTAT Jelang Pemilu 2024: PDIP, Gerindra, dan Demokrat 3 Besar
# done[19] >> Pastikan Pemilih Meninggal, Petugas Pantarlih Luwu Cek Langsung ke Kuburan
# done[20] >> Duet Anies-Sandi Mencuat di Survei Voxpol, PKS: Siapa Saja Berpeluang
# done[21] >> Relawan Jokowi Akan Gelar Musra Lagi di 11 Provinsi, Terakhir di Jakarta
# done[22] >> Besok, PKS Deklarasi Resmi Anies Baswedan Capres 2024!
# done[23] >> Paloh Cerita Kunjungi PKS Sebelum Berkoalisi, Ungkit Rangkulan Persahabatan
# done[24] >> Elektabilitas NasDem Melesat Naik, Surya Paloh: Kami Terbiasa Rendah
# done[25] >> Cak Imin Beber Alasan Koalisi Gerindra-PKB Belum Umumkan Capres-Cawapres
# done[26] >> Ganjar Unggul Versi Litbang Kompas, PDIP Tetap Tunggu Arahan Megawati
# done[27] >> Kelakar Surya Paloh soal Cawapres Anies: Jangankan AHY, Saya Juga Cocok
# done[28] >> Cak Imin Buka Suara soal Potensi Duet dengan Anies di Pilpres 2024
# done[29] >> Banyak Proyek Hunian Mangkrak, Industri Properti Belum Sembuh dari Pandemi?
# done[30] >> AHY Dampingi Anies? Paloh: Potongan Ganteng, Lebih dari Pantas
# done[31] >> Bamsoet: Toleransi dalam Beragama Tak Boleh Hanya Bersifat Retorika
# done[32] >> Surya Paloh: Sikap Pemerintah Jelas Dukung Sistem Pemilu Terbuka
# done[33] >> TGB Dukung Gibran Maju Gubernur: Sunatullah...
# done[34] >> Respons Santai Cak Imin soal Gus Yahya Sebut Warga NU Tak Haram Pilih PAN
# done[35] >> Kabar Terkini Bocah Kembar Prabowo-Sandiaga yang Sempat Bikin Heboh
# done[36] >> AHY di Depan Paloh: Semoga Koalisi Perubahan Bisa Berlayar dan Menang
# done[37] >> AHY: Demokrat dan NasDem Terdepan Tolak Pemilu Coblos Partai!
# done[38] >> Gerindra soal Survei Litbang Kompas: Kami Semangat Tren Prabowo Stabil
# done[39] >> Gibran soal Kriteria Cagub Jateng PDIP Versi Bambang Pacul: Bukan Saya
# done[40] >> Anies Merosot di Survei Litbang Kompas, NasDem Yakin Pendukung Tak Jadi Sampel
# done[41] >> Bambang Pacul Beber Kriteria Cagub Jateng Pengganti Ganjar, Gibran: Bukan Saya
# done[42] >> AHY Suguhkan Masakan Spesial Favorit Paloh di Markas Demokrat, Apa Itu?
# done[43] >> Cegah Pencurian Data Pemilih, Bawaslu dan BSSN Bentuk Tim Keamanan Siber
# done[44] >> Survei Litbang Kompas Capres 2024: Ganjar Ungguli Prabowo dan Anies
# done[45] >> Dipayungi AHY, Surya Paloh Tiba di Markas Demokrat Matangkan Koalisi
# done[46] >> Survei Litbang Kompas: Ridwan Kamil Dominan di Figur Capres Alternatif
# done[47] >> Survei Litbang Kompas: Ganjar 25,3%, Prabowo 18,1%, Anies 13,1%
# done[48] >> Bawaslu Dorong Ada Penerjemah bagi Disabilitas Setiap Kampanye
# done[49] >> Jubir Partai Ummat Bicara Prabowo Sebagai 'Cadangan' Anies
# done[50] >> PD dan PKS Tak Iri Meski Elektabilitas NasDem Melesat Berkat Anies
# done[51] >> Klaim Brand Anies Dekat PKS, NasDem: Nggak Penting!
# done[52] >> Pileg 2024, PKB Bidik 14 Kursi DPRD Kabupaten Bandung
# done[53] >> Ternyata Tak Rahasia-rahasia Amat Kunjungan Biden ke Ukraina
# done[54] >> Komitmen Gelora Jabar Jadikan Anis Matta-Fahri Hamzah Pemimpin Indonesia
# done[55] >> Mangku Pastika-Gede Suardana Tampil 'Mesra' dalam Diskusi Kebangsaan
# done[56] >> Andre Rosiade Tegaskan Polarisasi Tak Diperlukan: Solusinya Prabowo Presiden
# done[57] >> Petugas Pantarlih Lumajang Coklit Data Pemilih 2024 Sambil Jualan Pentol
# done[58] >> Gus Yahya Tak Haramkan Warga NU Coblos PAN, PKB Jatim: Cambuk Buat Kami
# done[59] >> Suara NU Jadi Rebutan di Pemilu 2024, Pengamat: Mayoritas Masih Pilih PKB
# done[60] >> Pemprov Setop Pengadaan Mobil Listrik untuk Pejabat DKI di 2024
# done[61] >> PKS Rakernas Akhir Pekan Ini, Gelar Deklarasi Resmi Anies Capres?
# done[62] >> PDIP Ungkap 3 Kriteria Pengganti Ganjar di Pilgub Jateng 2024
# done[63] >> Mahfud Md Gelar Pertemuan dengan Sejumlah Eks Menteri, Ada Apa?
# done[64] >> PDIP Beberkan 3 Kriteria Pengganti Ganjar di Pilgub Jateng 2024, Apa Saja?
# done[65] >> Reaksi Rusia Atas Kunjungan Mendadak Biden ke Ukraina
# done[66] >> Cak Imin soal Capres-cawapres 2024: Semua Stuck Nunggu Kartu Lawan
# done[67] >> PKS Tak Iri Survei NasDem Naik di Litbang Kompas, Tetap Dukung Anies
# done[68] >> PKB Umumkan Menaker Ida Fauziyah Maju Caleg 2024
# done[69] >> Cak Imin Belum Terpikir Sama Sekali Berpasangan dengan Anies di 2024
# done[70] >> PPP Heran Waketum PKB Banding-bandingkan Kursi Partai Ijo di DPR
# done[71] >> Demokrat: Maklum Survei NasDem Naik di Litbang Kompas, Efek Anies
# done[72] >> Cak Imin: Kalau Putusan MK Pemilu Tertutup, Negeri Ini Sedang Dangerous
# done[73] >> Pantarlih Mulai Lakukan Coklit Daftar Pemilih Pemilu 2024, Begini Prosesnya
# done[74] >> Adu Perspektif: Anies Vs Prabowo, Siapa Bisa Rebut Suara 'Umat'?
# done[75] >> Waketum PKB: Jangan Sampai PKB Kayak Partai Ijo Lain Cuma 19 Kursi
# done[76] >> Besok, Surya Paloh Makan Siang Bareng AHY di DPP Demokrat
# done[77] >> Survei Litbang Kompas: Prabowo Jadi Ketum Parpol Paling Disukai
# done[78] >> Menpora Amali Mundur Informal, Jokowi Reshuffle Mini atau Besar-besaran?
# done[79] >> Survei Litbang Kompas: NasDem Melesat, Demokrat-PKS Merosot
# done[80] >> 2 Kasat di Polres Klaten Dimutasi ke Polda Jateng
# done[81] >> Gaet 4 Gus, Begini Peluang PAN Rebut Ceruk Suara NU di Pemilu 2024
# done[82] >> PAN Jatim Blak-blakan Alasan Gaet 4 Gus dari NU
# done[83] >> KPU: Disabilitas hingga Ibu Hamil Tak Akan Antre saat Pencoblosan di 2024
# done[84] >> Prananda Paloh Optimis NasDem Raih 100 Kursi DPR di Pemilu 2024
# done[85] >> Momen Plt Ketum PPP Sowan ke Ponpes Tertua di Makassar
# done[86] >> Ketum Muhammadiyah Haedar Nashir Minta Parpol Tak Hanya Kejar Kepuasan
# done[87] >> Bawaslu Beberkan Kerawanan Pemilu 2024: Netralitas-Polarisasi Masyarakat
# done[88] >> Badung Petakan 1.481 TPS di Pemilu 2024
# done[89] >> Ray Rangkuti Sorot Aturan Dana Kampanye, Ungkit Perjanjian Utang Rp 50 M
# done[90] >> Gibran Semobil dengan MenPAN-RB Azwar Anas, Bahas Pilgub DKI?
# done[91] >> Bawaslu: Ada 18 Potensi Pelanggaran Kampanye, Paling Besar soal APK
# done[92] >> Ditanya soal Eks GP Mania Dukung Prabowo, Ganjar: Minyakita Mesti Kita Bereskan
# done[93] >> Bawaslu Sebut Aturan Kampanye di Medsos Lemah: Bahkan Hampir Tidak Ada
# done[94] >> PKB Tolak Sistem Coblos Partai: Akan Jadi Pintu Masuk Kekacauan Pemilu 2024
# done[95] >> NasDem ke Bawaslu: Anies Keliling Tak Langgar Aturan, Jangan Dengki!
# done[96] >> Gabung PAN, Crazy Rich Surabaya Tom Liwafa Berencana Nyaleg DPR RI
# done[97] >> Crazy Rich Surabaya Tom Liwafa Beber Alasan Banting Setir Masuk Politik
# done[98] >> Tata Kelola Pengawasan Pemilu
# done[99] >> Prediksi Serangan Siber Naik Jelang Pemilu, BSSN Siapkan Operasi Keamanan
# done[100] >> Bawaslu Awasi Hak Kelompok Disabilitas untuk Memilih Saat Pemilu 2024
# done[101] >> Capres Minus Legasi, Koalisi Butuh Legitimasi
# done[102] >> The Matchmaker Tahap Kedua Dimulai! Pilih Duet Capres-Cawapres Favoritmu
# done[103] >> Balas Bawaslu, Elite Demokrat Minta Bacapres Pejabat Aktif Diawasi
# done[104] >> Musim Kongkow Politik
# done[105] >> Sulut Jadi Provinsi Paling Rawan Pemilu 2024, Bawaslu Minta Waspada
# done[106] >> PKS Jawab Bawaslu Soal 'Capres Itu' Keliling Terus: Santuy Aja
# done[107] >> HNW: Jika Insan Pers Sehat, Maka Produk yang Dihasilkan Akan Sehat
# done[108] >> JoMan Jawab Sindiran PDIP: Dulu Saya Dukung Ganjar Malah Diserang
# done[109] >> Mengatur Ruang Kosong Sebelum Kampanye 2024
# done[110] >> Walkot Cilegon Pindah ke Gerindra Usai Berkarya Tak Lolos Pemilu 2024
# done[111] >> Panas PDIP vs Demokrat Usai SBY Beri Catatan Soal Gugatan Sistem Pemilu
# done[112] >> Ahmad Basarah Ungkap 3 Pelajaran Penting Isra Mi'raj bagi RI
# done[113] >> KPU Jawab Usulan Partai Ummat soal Libatkan Parpol Saat Penghitungan Suara
# done[114] >> KPU Jamin Hak Pilih Para Disabilitas
# done[115] >> PKB ke PDIP soal Koalisi: Sampai Saat Ini Belum Ada Capres-Cawapres Resmi
# done[116] >> PPP ke PDIP: KIB Terbuka Nambah Anggota, Duduk Bersama
# done[117] >> Isu Sandiaga Uno Gabung PPP Belum Sirna
# done[118] >> Sambutan Hangat Demokrat Usai Jokowi Sebut AHY Capres-cawapres 2024
# done[119] >> Demokrat Curiga Hasto Ngotot Pemilu Tertutup, Senggol Kasus Harun Masiku
# done[120] >> Sederet Catatan SBY soal Gugatan Sistem Pemilu, Wanti-wanti MK Keliru
# done[121] >> Partai Berkarya Akan Tentukan Dukungan Capres Cawapres Pada Pemilu 2024
# done[122] >> Peneliti LIPI Nilai Sistem Pemilu Terbuka Harusnya Diperbaiki Bukan Diganti
# done[123] >> Duet Ibul-Desy Ratnasari di Pilgub Jabar 2024, Sekjen PAN: Semua Berproses
# done[124] >> Di Acara Gerindra, Sandi Akan Lapor Prabowo soal Beban Ekonomi Rakyat
# done[125] >> KPU Siapkan Aturan Dana Sosialisasi Parpol
# done[126] >> Kisi-kisi Calon Mitra Koalisi PDIP
# done[127] >> Survei Parpol SPIN: PDIP Teratas, Disusul Gerindra dan Golkar
# done[128] >> Bawaslu Bicara Sosialisasi Kampanye, Singgung Capres Itu Keliling Terus
# done[129] >> Galang Dukungan, Relawan Ganjar di Lampung Bentuk Posko 'Degan Ijo'
# done[130] >> Bamsoet Usul Pemilu 2024 Digelar dengan Sistem Terbuka dan Tertutup
# done[131] >> Perludem Minta Jual Beli Suara di Pemilu Diantisipasi: Jadi Sumber Korupsi
# done[132] >> RK, Erick Thohir dan Ganjar Jadi 3 Besar Cawapres Terkuat Survei SPIN
# done[133] >> Disebut Jokowi di Daftar Capres-cawapres, Erick Thohir Ungkit PT 20%
# done[134] >> Gerindra Target Menang Pemilu 2024 Banten, Yakin Suara Lebih Besar dari 2019
# done[135] >> PPATK Ungkap Indikasi Praktik TPPU di Pemilu, Bawaslu Beri Saran Ini
# done[136] >> Gerindra Siap Perjuangkan Harga Sembako Turun Jelang Ramadhan
# done[137] >> Kader Gelora Deklarasi Anis Matta-Fahri Hamzah Capres dan Cawapres 2024
# done[138] >> Sentilan Menohok PDIP ke Partai Ummat soal Politik Identitas
# done[139] >> Survei Capres 2024 SPIN: Prabowo 33%, Ganjar 20,6% dan Anies 20%
# done[140] >> Riuh Wacana Coblos Partai, Bawaslu Ingatkan Tahapan Pemilu Sudah Dimulai
# done[141] >> Hasto PDIP Balas SBY: Dia Lupa Demokrat Pernah Ganti Sistem Pemilu di 2008!
# done[142] >> BEM UI Sebut Wacana Tunda Pemilu 2024 Bikin Resah Publik, KPU Jawab Begini
# done[143] >> Sesuai UU Pemilu, KPU Tegaskan Masih Gunakan Sistem Coblos Gambar Caleg
# done[144] >> Ungkit soal Antitesis, PDIP Beri Analogi Beda Jokowi dan Anies soal Tol
# done[145] >> Jokowi Sempat Lupa Sapa AHY Capres di Harlah PPP, PDIP Bilang Begini
# done[146] >> Bamsoet Soal Kriteria Capres: Komitmen Teruskan Program Jokowi Termasuk IKN
# done[147] >> Hasto Ungkap PDIP Akan Kerja Sama dengan Koalisi yang Belum Usung Capres
# done[148] >> Bamsoet Usul Sistem Kombinasi Tertutup dan Terbuka, Ungkit Pemilu Jerman
# done[149] >> Dasco hingga Sandi Kompak di Acara Gerindra: Dukungan Penuh untuk Prabowo
# done[150] >> Adian Napitupulu Cs Tak Mau Capres Afilisasi Orba-Politik Identitas
# done[151] >> Gerindra Gelar Pesta Rakyat di Banten, Minta Dukung Prabowo Presiden 2024
# done[152] >> Habiburokhman soal Isu Sandiaga ke PPP: Bukan Soal Restu, tapi...
# done[153] >> Gerindra Deklarasi Pemilu Damai 2024 di Jaktim, Yakin Prabowo Menang
# done[154] >> Hasto Sematkan Jaket PDIP ke Menteri Teten: Beliau juga Kader
# done[155] >> Ketegasan NU Tolak Politik Identitas Jadi Senjata Politik di Pemilu 2024
# done[156] >> Hasto Minta Publik Sabar soal Capres PDIP: Tunggu Momentum Terbaik
# done[157] >> Usai Anak Haji Lulung, Ketua Bamus Betawi Juga Gabung NasDem
# done[158] >> JoMan Kini Dukung Prabowo, Hasto PDIP Singgung 'Pagi Kedelai Sore Tempe'
# done[159] >> SBY: Apakah Ada Kegentingan Sistem Pemilu Mesti Diganti di Tengah Jalan?
# done[160] >> Kala Wagub Uu Keliru Tafsirkan Ucapan RK soal Pilgub 2024
# done[161] >> Ada Capres Dukungan Jokowi Absen Harlah PPP, PPI: Jelas Bukan Anies
# done[162] >> Rapatkan Barisan Kader PDIP Jatim, Said Abdullah Siapkan Caleg Petarung
# done[163] >> Ditanya Kabar Wiranto Gabung PAN, Zulhas Malah Jelaskan Soal Minyakita
# done[164] >> Respons Zulhas Soal PBNU Tak Haramkan Nahdliyin Pilih PAN
# done[165] >> Mardiono soal Klaim Prabowo Izinkan Sandi Gabung PPP: Implisit Belum Ada
# done[166] >> Gus Yahya Tegaskan NU Tolak Politik Identitas
# done[167] >> Di Hadapan Kader PAN, Gus Yahya: Warga NU Tidak Haram Coblos PAN
# done[168] >> Tak Pakai Blanko Lagi, Begini Cara Buat KTP Digital Terbaru 2023
# done[169] >> Kala Jokowi Hampir Lupa Nama AHY Saat Sapa Capres-Cawapres di Harlah PPP
# done[170] >> PAN Berbunga-bunga Jika PDIP Gabung ke KIB
# done[171] >> PKB: Keputusan PDIP Akan Ubah Peta Koalisi yang Ada
# done[172] >> Respons NasDem dan PKS Usai AHY Disebut Jokowi Jadi Capres-Cawapres
# done[173] >> Konsolidasi Pemilu 2024, Kader PDIP Sumenep Gelar Senam Sicita
# done[174] >> Mardiono Ungkap Akan Ada Jenderal Polisi Bintang 3 Gabung PPP
# done[175] >> Ketum PPP Ngaku Siap Hadapi Pemilu Proporsional Terbuka atau Tertutup
# done[176] >> Sandiaga soal Isu Pindah PPP: Prabowo dan Mardiono Akan Bertemu
# done[177] >> Ketua Bawaslu: Jangan Sampai Indonesia Hanya Dikuasai Segelintir Orang
# done[178] >> Biaya Haji 2023 Diputuskan Jadi Rp 49 Juta, Gerindra Terima Kasih ke Jokowi
# done[179] >> KoDE Bali Minta DKPP Hindari Intervensi Jelang Pemilu 2024
# done[180] >> Politisi PAN Tolak Pemilu Coblos Partai: Terbuka Lebih Elegan
# done[181] >> Sekjen PAN Tak Sangkal Wiranto Mau Gabung: Tempati Posisi Sangat Terhormat
# done[182] >> Ketua Bawaslu Tolak Politisasi SARA, Tak Setuju Kampanye di Tempat Ibadah
# done[183] >> Jokowi Ungkap Ada Capres Dukungannya Tidak Hadir di Harlah PPP, Siapa?
# done[184] >> Minta Pemilu 2024 Aman, Jokowi Ingatkan Jangan Sampai RI Jadi Pasien IMF
# done[185] >> Jokowi Bantah Kasih Arahan soal Pemilu Coblos Gambar Partai
# done[186] >> Namanya Disebut Jokowi di Daftar Capres-Cawapres, Begini Respons AHY
# done[187] >> Jokowi Sebut Erick Thohir, Sandiaga, hingga Prabowo Bakal Capres & Cawapres
# done[188] >> Bendera-Nomor Urut Parpol Boleh Dipasang, Tapi Hanya di Acara Internal
# done[189] >> Di Depan Jokowi, PPP Bantah Kesulitan Dapatkan Caleg
# done[190] >> Jokowi Sapa Bakal Capres-Cawapres di Harlah PPP: Hampir Lupa, Ada Mas AHY
# done[191] >> Bahas Capres-Cawapres di Harlah PPP, Jokowi Sebut Prabowo hingga Mahfud
# done[192] >> Jokowi: Target 39 Kursi DPR di 2024 Bukan Barang Sulit Bagi PPP
# done[193] >> Zulhas Respons Kabar Wiranto Gabung PAN
# done[194] >> Erick hingga Sandi Hadir, Plt Ketum PPP Singgung Cawapres di Depan Jokowi
# done[195] >> Mardiono Sapa Sandiaga Uno, Peserta Harlah Ke-50 PPP Riuh
# done[196] >> Disebut Restui Uu Maju Cagub Jabar, RK: Saya Bilang 'Saya Doakan'
# done[197] >> PKB Sebut Penentuan Capres di Tangan Prabowo-Cak Imin Jika KIB Gabung
# done[198] >> Berbatik Hijau, Jokowi Hadiri Puncak Peringatan Harlah ke-50 PPP
# done[199] >> Soal 9 Hakim MK Dipolisikan, Anwar Usman: Sedang Diperiksa MKMK
# done[200] >> Ridwan Kamil Bantah Restui Uu Ruzhanul Maju Jadi Cagub Jabar
# done[201] >> Masa Kampanye Belum Mulai, KPU Minta Parpol Tahan Diri!
# done[202] >> Mantan Ketua DPW Perindo NTB Gabung NasDem
# done[203] >> Pihak Wiranto Buka Suara soal Kabar Gabung PAN
# done[204] >> Harap AHY Jadi Wakilnya Anies, Demokrat Siapkan 2 Strategi untuk 2024
# done[205] >> Isi Pertemuan Jokowi dan Prabowo di Istana Kemarin
# done[206] >> Partai Garuda: Relawan Pindah Dukungan Itu Biasa, Parpol Juga Bisa
# done[207] >> Kian Terang Kabar Wiranto Bergabung ke PAN
# done[208] >> Manuver JoMan Pakai Setelan ala Gerindra Usai Dukung Prabowo
# done[209] >> Dana Hibah Pilbup Badung 2020 Rp 29,2 Miliar
# done[210] >> Tanda Tanya Isi Pertemuan Jokowi dan Prabowo di Istana
# done[211] >> Masinton Minta Maaf PDIP Tak Bisa Gabung Pro Anies, Demokrat Memaklumi
# done[212] >> Masinton Bilang PDIP Tak Bisa Ikut Pro Anies, NasDem: Tak Gabung Juga Bagus
# done[213] >> Politisi Muda Harus Kedepankan Kepentingan Warga di Pemilu 2024
# done[214] >> Polda Bali Petakan Tingkat Kerawanan TPS-Siapkan Personel untuk Pemilu
# done[215] >> BPIP Bentuk Tim Evaluasi UU Pemilu, Bahas Sistem Terbuka Terbatas
# done[216] >> Respons PPP soal Pengurus dan Kader Ramai-ramai Loncat ke NasDem Riau
# done[217] >> Jelang Pemilu, Bawaslu Jabar Soroti TPS di Daerah Rawan Bencana
# done[218] >> Sebut Kepemimpinan Jokowi Berhasil, Prabowo Berniat Meneruskan
# done[219] >> Usai Bertemu JoMan, Prabowo Diyakini Bisa Teruskan Perjuangan Jokowi
# done[220] >> Masinton PDIP Bicara Jumlah Pasangan Capres Ideal, Singgung Duet Mega-Prabowo
# done[221] >> Masih Sakit, Suharso Monoarfa Tak Akan Hadir di Harlah PPP Besok
# done[222] >> Migrasi Relawan dari Ganjar ke Prabowo Cerminan Sikap Jokowi?
# done[223] >> Prabowo soal Isi Pertemuan dengan Jokowi: Itu Namanya 'RHS'
# done[224] >> Prabowo: Kepemimpinan Jokowi Berhasil, Saya Berniat Meneruskan!
# done[225] >> Canda Prabowo soal Muka Kudeta di Depan Noel JoMan
# done[226] >> Masinton Minta Maaf PDIP Tak Bisa Sama Pro Anies, Jawaban PKS Bikin Ketawa
# done[227] >> Canda Masinton Gabung Fans Klubnya Puan Maharani, Apa Itu?
# done[228] >> Muncul Ormas Berkarya Usai Partai Berkarya Gagal Ikut Pemilu 2024, Apa Itu?
# done[229] >> Gerindra: Cak Imin Termasuk Calon Kuat Cawapres Prabowo
# done[230] >> Berapa Jumlah Partai Peserta Pemilu 2024? Cek Daftar dan Nomor Urutnya
# done[231] >> Bagaimana Teknis Pemungutan Suara Pemilu 2024? Simak Info Lengkapnya
# done[232] >> Apa Saja Perlengkapan Pemungutan Suara Pemilu 2024? Cek di Sini
# done[233] >> Pengawas TPS Pemilu 2024: Tugas dan Syarat Pendaftaran PTPS
# done[234] >> Gerindra Harap JoMan Tulus Dukung Prabowo Meski Pernah Minta Ditangkap
# done[235] >> Pakai Setelan Ala Gerindra, Relawan JoMan Temui Prabowo di Kertanegara
# done[236] >> Kodam Udayana Monitor Tahapan Pemilu, Backup Polisi untuk Pengamanan
# done[237] >> Sri Mulyani Gelontorkan Rp 22 T buat Anggaran Persiapan Pemilu di 2023
# done[238] >> Elite Hanura Dengar Kabar Wiranto Merapat ke PAN
# done[239] >> Masinton: PDIP Bisa ke KKIR-KIB, Kalau Koalisi Perubahan Mohon Maaf Bang
# done[240] >> Arsul Sani Ungkap Khofifah Juga Diharapkan Kader PPP Jadi Cawapres
# done[241] >> Kata Menkumham Yasonna soal Wacana Pemilu Coblos Gambar Partai
# done[242] >> Kreatif! 5 Tempat Makan Ini Pakai Spanduk ala Caleg Kampanye
# done[243] >> Andika Kangen Band Bakal Nyaleg DPR RI dari Demokrat, Ini Katanya
# done[244] >> Ganjar Mania Bubar-Dukung Prabowo, FX Rudy: Lha Sing Ngakon Bentuk Sopo?
# done[245] >> PAN Serang Balik Gatot Nurmantyo soal Partai Ummat: Evaluasi Apaan?
# done[246] >> JoMan Dukung Prabowo, Bambang Pacul Singgung soal Dewan Kopral
# done[247] >> Ketum JoMan Temui Prabowo di Kertanegara Sore Ini
# done[248] >> Warga dari 5 Kecamatan di Kediri Kompak Dukung Ganjar Maju Pilpres
# done[249] >> Sindiran Amien Rais ke Prabowo Gara-gara Susah Ketemuan
# done[250] >> Dukungan JoMan ke Prabowo di 2024 Dinilai Bagian Sikap Politik Istana
# done[251] >> Ganti Nama Jokowi Mania Usai Dukungan Berpaling dari Ganjar ke Prabowo
# done[252] >> Restu Ridwan Kamil untuk Uu Ruzhanul di Pilgub Jabar
# done[253] >> Sambut JoMan, Gerindra: Gerbong Dukungan ke Prabowo Kian Panjang
# done[254] >> Waketum PPP: DPR Nggak Pernah Bicara soal Pemilu Ditunda
# done[255] >> Jabar Hari Ini: Suara Hati Lucky Hakim yang Ingin Mundur
# done[256] >> Meski Dukung Anies, Amien Rais Doakan Prabowo yang Ingin Jadi Presiden
# done[257] >> Gus Muhaimin Prediksi Tak Lama Lagi Bakal Ada Koalisi Baru untuk Pilpres 2024
# done[258] >> Ketum JoMan Dulu Serang Prabowo, Kini Dukung Nyapres
# done[259] >> Tetap 'Budal' Nyapres, Gus Muhaimin Pasrahkan ke Takdir Nanti Dapatnya Apa
# done[260] >> Terima Mandat Kades se-Jatim, Gus Muhaimin: APBN Rp 5 Miliar Per Desa
# done[261] >> Partai Ummat Capreskan Anies, NasDem Sebut Politik Identitas Tak Salah
# done[262] >> Uu Ruzhanul Kantongi Restu Ridwan Kamil untuk Jadi Cagub Jabar
# done[263] >> Amien Rais Curhat 3 Bulan Hubungi Prabowo Tapi Tak Pernah Diangkat
